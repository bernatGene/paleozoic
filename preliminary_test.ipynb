# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !pip install imageio
# Out:
# Collecting imageio
#   Downloading imageio-2.9.0-py3-none-any.whl (3.3 MB)
#      |################################| 3.3 MB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from imageio) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio) (8.1.0)
# Installing collected packages: imageio
# Successfully installed imageio-2.9.0
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import cv2
import os
import glob
import imageio
from IPython.display import HTML, Image

# %% [markdown]
# ## Environment

# %%
UP = (-1, 0)
DOWN = (1, 0)
LEFT = (0, -1)
RIGHT = (0, 1)
STAY = (0, 0)
ACTIONS = [UP, DOWN, LEFT, RIGHT, STAY]

# %%
def num2act(num):
    return ACTIONS[num]

# %%
class Pangea:
    def __init__(self, field_size):
        self.field_size = field_size
        self.field = np.random.rand(field_size+4, field_size+4)
        self.reset_field()
    
    def perception(self):
        px = self.agent_pos[0]
        py = self.agent_pos[1]
        percep = self.field[px-2:px+3, py-2:py+3].copy()
        return percep
        
    def move_and_consume(self, action):
        self.agent_pos[0] += action[0]
        self.agent_pos[1] += action[1]
        food = self.field[self.agent_pos[0], self.agent_pos[1]]
        self.field[self.agent_pos[0], self.agent_pos[1]] = 0
        return self.perception(), food
        
    def act(self, action):
        y = self.agent_pos[0]
        x = self.agent_pos[1]
        y += action[0]
        x += action[1]
        if self.field[y, x] == -1:
            return self.perception(), 0
        return self.move_and_consume(action)
    
    def show_field(self):
        field = self.field.copy()
        field[self.agent_pos[0], self.agent_pos[1]] = -3
        plt.imshow(field)
    
    def get_field(self):
        field = self.field.copy()
        field[self.agent_pos[0], self.agent_pos[1]] = -3
        return field
        
    def reset_field(self):
        fs = self.field_size
        self.field = np.random.rand(fs+4, fs+4)
        self.field[self.field < 0.8] = 0
        self.field[0:2,:] = -1
        self.field[fs+2:,:] = -1
        self.field[:,0:2] = -1
        self.field[:,fs+2:] = -1
        self.agent_pos = [15, 15]
        return self.perception()

# %% [markdown]
# ## Agent

# %%
class Zoe:
    def __init__(self):
        input_size = (5, 5)
        num_actions = 4 # up, down, left, right, stay
        num_hidden = 256
        inputs = layers.Input(shape=(input_size))
        x = layers.Flatten()(inputs)
        x = layers.Dense(num_hidden, activation="relu")(x)
        common = layers.Dense(num_hidden, activation="relu")(x)
        action = layers.Dense(num_actions, activation="softmax")(common)
        critic = layers.Dense(1)(common)
        self.model = keras.Model(inputs=inputs, outputs=[action, critic])
        self.optimizer = keras.optimizers.Adam(learning_rate=0.0005)
        self.huber_loss = keras.losses.Huber()
        self.action_probs_history = []
        self.critic_value_history = []
        self.rewards_history = []
        self.digested = 0
    
    def decision(self, percep):
        return self.model(np.expand_dims(percep, 0))

# %% [markdown]
# ## Train

# %%
gamma = 0.99
steps_per_day = 500
eps = np.finfo(np.float32).eps.item()  # Smallest number such that 1.0 + eps != 1.0

# %%
num_days = 1000
pan = Pangea(32)
zoe = Zoe()

# %%
zoe.model = tf.keras.models.load_model("model")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
running_reward = 0
for d in range(num_days):
    percep = pan.reset_field()
    day_reward = 0
    with tf.GradientTape() as tape:
        zoe.digested = 10
        for timestep in range(1, steps_per_day):
            if percep.shape != (5,5):
                print(percep.shape)
                print(pan.agent_pos)
            action_probs, critic_value = zoe.decision(percep)
            zoe.critic_value_history.append(critic_value[0, 0])
            action = np.random.choice(4, p=np.squeeze(action_probs))
            zoe.action_probs_history.append(tf.math.log(action_probs[0, action]))
            percep, food = pan.act(num2act(action))
            zoe.digested += food
            zoe.digested -= 0.3
            reward = zoe.digested
            zoe.rewards_history.append(reward)
            day_reward += reward
            
            if reward < 0:
                break
        running_reward = 0.05 * day_reward + (1 - 0.05) * running_reward
        returns = []
        discounted_sum = 0
        for r in zoe.rewards_history[::-1]:
            discounted_sum = r + gamma * discounted_sum
            returns.insert(0, discounted_sum)

        # Normalize
        returns = np.array(returns)
        returns = (returns - np.mean(returns)) / (np.std(returns) + eps)
        returns = returns.tolist()
        
        history = zip(zoe.action_probs_history, zoe.critic_value_history, returns)
        actor_losses = []
        critic_losses = []
        for log_prob, value, ret in history:
            diff = ret - value
            actor_losses.append(-log_prob * diff)  # actor loss
            # The critic must be updated so that it predicts a better estimate of
            # the future rewards.
            critic_losses.append(
                zoe.huber_loss(tf.expand_dims(value, 0), tf.expand_dims(ret, 0))
            )
        # Backpropagation
        loss_value = sum(actor_losses) + sum(critic_losses)
        grads = tape.gradient(loss_value, zoe.model.trainable_variables)
        zoe.optimizer.apply_gradients(zip(grads, zoe.model.trainable_variables))

        # Clear the loss and reward history
        zoe.action_probs_history.clear()
        zoe.critic_value_history.clear()
        zoe.rewards_history.clear()
        
    if d%10 ==0:
        template = "running reward: {:.2f} at episode {}"
        print(template.format(running_reward, d))
        print(f"Zoe digested: {zoe.digested}")
        zoe.digested = 0
        zoe.model.save('model')
# Out:
# running reward: 9.83 at episode 0
# Zoe digested: -0.01651618529356791
# INFO:tensorflow:Assets written to: model/assets
# running reward: 102.59 at episode 10
# Zoe digested: -0.1970384935136174
# INFO:tensorflow:Assets written to: model/assets
# running reward: 168.02 at episode 20
# Zoe digested: -0.07931325897293362
# INFO:tensorflow:Assets written to: model/assets
# running reward: 196.39 at episode 30
# Zoe digested: -0.17201967668729884
# INFO:tensorflow:Assets written to: model/assets
# running reward: 224.66 at episode 40
# Zoe digested: -0.14073071051461722
# INFO:tensorflow:Assets written to: model/assets
# running reward: 227.16 at episode 50
# Zoe digested: -0.17157272385379657
# INFO:tensorflow:Assets written to: model/assets
# running reward: 243.95 at episode 60
# Zoe digested: -0.21302631633675234
# INFO:tensorflow:Assets written to: model/assets
# running reward: 261.76 at episode 70
# Zoe digested: -0.1357667036861397
# INFO:tensorflow:Assets written to: model/assets
# running reward: 267.65 at episode 80
# Zoe digested: -0.09470418317193785
# INFO:tensorflow:Assets written to: model/assets
# running reward: 276.63 at episode 90
# Zoe digested: -0.15961804619308123
# INFO:tensorflow:Assets written to: model/assets
# running reward: 280.57 at episode 100
# Zoe digested: -0.27847051081364055
# INFO:tensorflow:Assets written to: model/assets
# running reward: 283.89 at episode 110
# Zoe digested: -0.24373519559641715
# INFO:tensorflow:Assets written to: model/assets
# running reward: 281.06 at episode 120
# Zoe digested: -0.24628145211710734
# INFO:tensorflow:Assets written to: model/assets
# running reward: 291.34 at episode 130
# Zoe digested: -0.25963372242735977
# INFO:tensorflow:Assets written to: model/assets
# running reward: 295.52 at episode 140
# Zoe digested: -0.020686998093837006
# INFO:tensorflow:Assets written to: model/assets
# running reward: 287.88 at episode 150
# Zoe digested: -0.05133511846322503
# INFO:tensorflow:Assets written to: model/assets
# running reward: 289.25 at episode 160
# Zoe digested: -0.12843282886706736
# INFO:tensorflow:Assets written to: model/assets
# running reward: 285.99 at episode 170
# Zoe digested: -0.2843580786371385
# INFO:tensorflow:Assets written to: model/assets
# running reward: 286.65 at episode 180
# Zoe digested: -0.13711066073669348
# INFO:tensorflow:Assets written to: model/assets
# running reward: 306.64 at episode 190
# Zoe digested: -0.18265996230376375
# INFO:tensorflow:Assets written to: model/assets
# running reward: 306.59 at episode 200
# Zoe digested: -0.28364524445512834
# INFO:tensorflow:Assets written to: model/assets
# running reward: 306.27 at episode 210
# Zoe digested: -0.2486717123650331
# INFO:tensorflow:Assets written to: model/assets
# running reward: 299.78 at episode 220
# Zoe digested: -0.07001364739856586
# INFO:tensorflow:Assets written to: model/assets
# running reward: 298.75 at episode 230
# Zoe digested: -0.19687580161462287
# INFO:tensorflow:Assets written to: model/assets
# running reward: 312.78 at episode 240
# Zoe digested: -0.1628509738788531
# INFO:tensorflow:Assets written to: model/assets
# running reward: 320.27 at episode 250
# Zoe digested: -0.09491327582401576
# INFO:tensorflow:Assets written to: model/assets
# running reward: 314.40 at episode 260
# Zoe digested: -0.1997478831341562
# INFO:tensorflow:Assets written to: model/assets
# running reward: 323.88 at episode 270
# Zoe digested: -0.003405237822699747
# INFO:tensorflow:Assets written to: model/assets
# running reward: 317.07 at episode 280
# Zoe digested: -0.15953931051966191
# INFO:tensorflow:Assets written to: model/assets
# running reward: 318.04 at episode 290
# Zoe digested: -0.17877499925032653
# INFO:tensorflow:Assets written to: model/assets
# running reward: 316.63 at episode 300
# Zoe digested: -0.1320305474468098
# INFO:tensorflow:Assets written to: model/assets
# running reward: 287.57 at episode 310
# Zoe digested: -0.28509708987398136
# INFO:tensorflow:Assets written to: model/assets
# running reward: 272.09 at episode 320
# Zoe digested: -0.018847204197980916
# INFO:tensorflow:Assets written to: model/assets
# running reward: 254.92 at episode 330
# Zoe digested: -0.1131788458936745
# INFO:tensorflow:Assets written to: model/assets
# running reward: 258.55 at episode 340
# Zoe digested: -0.24190887342901207
# INFO:tensorflow:Assets written to: model/assets
# running reward: 260.82 at episode 350
# Zoe digested: -0.05145546338977047
# INFO:tensorflow:Assets written to: model/assets
# running reward: 252.26 at episode 360
# Zoe digested: -0.19185332193213128
# INFO:tensorflow:Assets written to: model/assets
# running reward: 248.82 at episode 370
# Zoe digested: -0.2967609140075618
# INFO:tensorflow:Assets written to: model/assets
# running reward: 235.41 at episode 380
# Zoe digested: -0.1793374192707205
# INFO:tensorflow:Assets written to: model/assets
# running reward: 249.69 at episode 390
# Zoe digested: -0.20031245250118307
# INFO:tensorflow:Assets written to: model/assets
# running reward: 251.88 at episode 400
# Zoe digested: -0.07967598519639141
# INFO:tensorflow:Assets written to: model/assets
# running reward: 247.36 at episode 410
# Zoe digested: -0.05856680053977714
# INFO:tensorflow:Assets written to: model/assets
# running reward: 270.50 at episode 420
# Zoe digested: -0.20419946132658034
# INFO:tensorflow:Assets written to: model/assets
# running reward: 278.17 at episode 430
# Zoe digested: -0.11370170319954936
# INFO:tensorflow:Assets written to: model/assets
# running reward: 285.05 at episode 440
# Zoe digested: -0.19842920827925098
# INFO:tensorflow:Assets written to: model/assets
# running reward: 299.82 at episode 450
# Zoe digested: -0.12035350311009091
# INFO:tensorflow:Assets written to: model/assets
# running reward: 293.19 at episode 460
# Zoe digested: -0.0343462944984273
# INFO:tensorflow:Assets written to: model/assets
# running reward: 290.86 at episode 470
# Zoe digested: -0.14690991868343845
# INFO:tensorflow:Assets written to: model/assets
# running reward: 293.27 at episode 480
# Zoe digested: -0.13515470812149194
# INFO:tensorflow:Assets written to: model/assets
# running reward: 288.63 at episode 490
# Zoe digested: -0.13954272193788936
# INFO:tensorflow:Assets written to: model/assets
# running reward: 273.19 at episode 500
# Zoe digested: -0.015135368760469725
# INFO:tensorflow:Assets written to: model/assets
# running reward: 271.64 at episode 510
# Zoe digested: -0.14718944548110696
# INFO:tensorflow:Assets written to: model/assets
# running reward: 277.34 at episode 520
# Zoe digested: -0.2782703953540509
# INFO:tensorflow:Assets written to: model/assets
# running reward: 292.34 at episode 530
# Zoe digested: -0.008824785369395571
# INFO:tensorflow:Assets written to: model/assets
# running reward: 293.84 at episode 540
# Zoe digested: -0.10220073875153785
# INFO:tensorflow:Assets written to: model/assets
# running reward: 295.03 at episode 550
# Zoe digested: -0.05157443672577655
# INFO:tensorflow:Assets written to: model/assets
# running reward: 285.29 at episode 560
# Zoe digested: -0.02524784256461532
# INFO:tensorflow:Assets written to: model/assets
# running reward: 276.96 at episode 570
# Zoe digested: -0.2693759885582006
# INFO:tensorflow:Assets written to: model/assets
# running reward: 278.97 at episode 580
# Zoe digested: -0.29782128544759906
# INFO:tensorflow:Assets written to: model/assets
# running reward: 289.43 at episode 590
# Zoe digested: -0.09757374664648577
# INFO:tensorflow:Assets written to: model/assets
# running reward: 281.01 at episode 600
# Zoe digested: -0.12578938734644113
# INFO:tensorflow:Assets written to: model/assets
# running reward: 283.28 at episode 610
# Zoe digested: -0.2576082504355746
# INFO:tensorflow:Assets written to: model/assets
# running reward: 271.46 at episode 620
# Zoe digested: -0.1852881026982383
# INFO:tensorflow:Assets written to: model/assets
# running reward: 255.23 at episode 630
# Zoe digested: -0.12841893511048214
# INFO:tensorflow:Assets written to: model/assets
# running reward: 250.52 at episode 640
# Zoe digested: -0.13095758765746252
# INFO:tensorflow:Assets written to: model/assets
# running reward: 279.76 at episode 650
# Zoe digested: -0.2303687077017907
# INFO:tensorflow:Assets written to: model/assets
# running reward: 277.30 at episode 660
# Zoe digested: -0.2000000000000009
# INFO:tensorflow:Assets written to: model/assets
# running reward: 278.53 at episode 670
# Zoe digested: -0.23710405951516772
# INFO:tensorflow:Assets written to: model/assets
# running reward: 284.72 at episode 680
# Zoe digested: -0.1293217879473561
# INFO:tensorflow:Assets written to: model/assets
# running reward: 265.81 at episode 690
# Zoe digested: -0.27079585715547433
# INFO:tensorflow:Assets written to: model/assets
# running reward: 247.24 at episode 700
# Zoe digested: -0.07736216743245239
# INFO:tensorflow:Assets written to: model/assets
# running reward: 246.99 at episode 710
# Zoe digested: -0.2627245594460073
# INFO:tensorflow:Assets written to: model/assets
# running reward: 258.08 at episode 720
# Zoe digested: -0.25763067178789073
# INFO:tensorflow:Assets written to: model/assets
# running reward: 265.17 at episode 730
# Zoe digested: -0.13690401824162773
# INFO:tensorflow:Assets written to: model/assets
# running reward: 253.18 at episode 740
# Zoe digested: -0.014373424541326174
# INFO:tensorflow:Assets written to: model/assets
# running reward: 252.14 at episode 750
# Zoe digested: -0.22168690833167465
# INFO:tensorflow:Assets written to: model/assets
# running reward: 250.86 at episode 760
# Zoe digested: -0.2212298273995395
# INFO:tensorflow:Assets written to: model/assets
# running reward: 254.99 at episode 770
# Zoe digested: -0.19687589785629528
# INFO:tensorflow:Assets written to: model/assets
# running reward: 249.94 at episode 780
# Zoe digested: -0.22136898713213854
# INFO:tensorflow:Assets written to: model/assets
# running reward: 258.81 at episode 790
# Zoe digested: -0.004108396597881758
# INFO:tensorflow:Assets written to: model/assets
# running reward: 269.50 at episode 800
# Zoe digested: -0.27144211980070027
# INFO:tensorflow:Assets written to: model/assets
# running reward: 259.79 at episode 810
# Zoe digested: -0.014800916053157143
# INFO:tensorflow:Assets written to: model/assets
# running reward: 271.66 at episode 820
# Zoe digested: -0.0704322355909831
# INFO:tensorflow:Assets written to: model/assets
# running reward: 271.16 at episode 830
# Zoe digested: -0.07822838649434127
# INFO:tensorflow:Assets written to: model/assets
# running reward: 254.21 at episode 840
# Zoe digested: -0.2081548685128583
# INFO:tensorflow:Assets written to: model/assets
# running reward: 250.47 at episode 850
# Zoe digested: -0.13333328290662722
# INFO:tensorflow:Assets written to: model/assets
# running reward: 253.22 at episode 860
# Zoe digested: -0.2556647557059131
# INFO:tensorflow:Assets written to: model/assets
# running reward: 269.74 at episode 870
# Zoe digested: -0.29772325581133413
# INFO:tensorflow:Assets written to: model/assets
# running reward: 273.47 at episode 880
# Zoe digested: -0.01219818707654563
# INFO:tensorflow:Assets written to: model/assets
# running reward: 279.03 at episode 890
# Zoe digested: -0.17164089567353785
# INFO:tensorflow:Assets written to: model/assets
# running reward: 273.57 at episode 900
# Zoe digested: -0.037586242450364904
# INFO:tensorflow:Assets written to: model/assets
# running reward: 281.50 at episode 910
# Zoe digested: -0.09569509211919469
# INFO:tensorflow:Assets written to: model/assets
# running reward: 293.26 at episode 920
# Zoe digested: -0.007057658354196472
# INFO:tensorflow:Assets written to: model/assets
# running reward: 288.76 at episode 930
# Zoe digested: -0.2612352690661402
# INFO:tensorflow:Assets written to: model/assets
# running reward: 262.48 at episode 940
# Zoe digested: -0.169596427189102
# INFO:tensorflow:Assets written to: model/assets
# running reward: 260.68 at episode 950
# Zoe digested: -0.026621106519455595
# INFO:tensorflow:Assets written to: model/assets
# running reward: 268.55 at episode 960
# Zoe digested: -0.21806437250652505
# INFO:tensorflow:Assets written to: model/assets
# running reward: 282.45 at episode 970
# Zoe digested: -0.27224705903463803
# INFO:tensorflow:Assets written to: model/assets
# running reward: 268.31 at episode 980
# Zoe digested: -0.24222270376844596
# INFO:tensorflow:Assets written to: model/assets
# running reward: 284.91 at episode 990
# Zoe digested: -0.08206314936843173
# INFO:tensorflow:Assets written to: model/assets

# %%
percep = pan.reset_field()

# %%
def gallery(images, captionsList=None, row_height='auto'):
    """Shows a set of images in a gallery that flexes with the width of the notebook.
    
    Parameters
    ----------
    images: list of str or bytes
        URLs or bytes of images to display
        
    captions: list of str
        Additional captions to be showed below the image name

    row_height: str
        CSS height value to assign to all images. Set to 'auto' by default to show images
        with their native dimensions. Set to a value like '250px' to make all rows
        in the gallery equal height.
    """
    figures = []
    for i, image in enumerate(images):
        if captionsList == None:
            captions = []
        else:
            captions = captionsList[i]
        if isinstance(image, bytes):
            src = _src_from_data(image)
            caption = ''
        else:
            src = image
            caption = f'<figcaption style="font-size: 0.6em">{image}'
            for c in captions:
                caption += f'<br>{c}'
            caption += f'</figcaption>'
        figures.append(f'''
            <figure style="margin: 5px !important;">
              <img src="{src}" style="height: {row_height}">
              {caption}
            </figure>
        ''')
    return HTML(data=f'''
        <div style="display: flex; flex-flow: row wrap; text-align: center;">
        {''.join(figures)}
        </div>
    ''')

# %%
plt.ioff()

# %%
# !rm "frames/*"
# Out:
# rm: cannot remove 'frames/*': No such file or directory

# %%
def create_gif(num_days, pan, zoe, event_name):
    percep = pan.perception()
    zoe.digested = 10
    for d in range(num_days):
        frame = pan.get_field()
        fig = plt.figure()
        plt.imshow(frame)
        plt.title(f'{d:04d}-{zoe.digested:2.3f}')
        fig.savefig(f'frames/frame{d:04d}.jpg')
        plt.close(fig)
        action_probs, critic_value = zoe.decision(percep)
        action = np.random.choice(4, p=np.squeeze(action_probs))
        percep, reward = pan.act(num2act(action))
        zoe.digested += reward - 0.3
    anim_file = os.path.join('gifs', event_name + '.gif')
    with imageio.get_writer(anim_file, mode='I') as writer:
        filenames = glob.glob('frames'+'/*.jpg')
        filenames = sorted(filenames)
        for filename in filenames:
            img = imageio.imread(filename)
            writer.append_data(img)
            os.remove(filename)
    return anim_file

# %%
pan = Pangea(32)

# %%
gif = create_gif(200, pan, zoe, "test")

# %%
gallery([gif])
# Out:
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="gifs/test.gif" style="height: auto">
#               <figcaption style="font-size: 0.6em">gifs/test.gif</figcaption>
#             </figure>
#
#         </div>
